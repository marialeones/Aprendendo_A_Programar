# %% [markdown]
# <a href="https://colab.research.google.com/github/marialeones/Aprendendo_A_Programar/blob/main/Aula_analise_de_dados_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ANALISE DE DADOS

# %% [markdown]
# Analisando uma tabela, visualizando valores nulos, tratamento de dados nulos e  utilização da biblioteca matplotlib.pyplot.

# %%
import pandas as pd

# %%
dfClientes = pd.read_excel('caso_estudo.xlsx', sheet_name='clientes')
dfLojas = pd.read_excel('/content/caso_estudo.xlsx', sheet_name = 'lojas')
dfProdutos = pd.read_excel('/content/caso_estudo.xlsx', sheet_name = 'produtos')
dfVendas = pd.read_excel('/content/caso_estudo.xlsx', sheet_name = 'vendas')
dfPag = pd.read_excel('/content/caso_estudo.xlsx', sheet_name = 'pagamentos')

# %%
dfClientes.sample(5)
# Out:
#       id                nome sexo     dt_nasc
# 274  275      Diego Oliveira    M  11/12/1958
# 403  404      Igor Fernandes    M    8/5/1949
# 834  835  Gabrielly Oliveira    F   10/9/1983
# 734  735      Sofia Oliveira    F  10/23/1937
# 581  582       Vitor Correia    M  12/18/1951

# %%
dfClientes.isnull().sum()
# Out:
# id         0
# nome       4
# sexo       4
# dt_nasc    4
# dtype: int64

# %%
dfClientes[dfClientes.isnull().T.any()]
# Out:
#       id               nome sexo     dt_nasc
# 263  264                NaN    F   7/29/1997
# 264  265                NaN    M    2/7/1979
# 268  269                NaN    F         NaN
# 269  270                NaN    M         NaN
# 276  277      Brenda Santos    F         NaN
# 282  283      Amanda Barros    F         NaN
# 287  288     Victor Ribeiro  NaN  12/17/1974
# 290  291        Clara Pinto  NaN  12/25/1980
# 294  295         Tiago Lima  NaN   7/26/1973
# 301  302  Guilherme Cardoso  NaN    3/9/1998

# %%
dfClientes.sexo.unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
dfProdutos
# Out:
#    id        produto      valor
# 0   1          mouse       20.0
# 1   2        teclado       30.0
# 2   3  laptop básico     2300.0
# 3   4   laptop gamer     5300.0
# 4   5        monitor     1500.0
# 5   6     impressora      700.0
# 6   7     carregador      150.0
# 7   8        cadeira      540.0
# 8   9           mesa      860.0
# 9  10       xxx-231a  3211352.0

# %%
dfProdutos.boxplot(column=['valor'])

# %%
dfProdutos[dfProdutos.valor>3000000]
# Out:
#    id   produto      valor
# 9  10  xxx-231a  3211352.0

# %%
dfProdutos[dfProdutos. valor < 3000000].boxplot(column=['valor'])

# %%
dfVendas[dfVendas.id_produto==10].count()
# Out:
# id            182
# id_cliente    182
# id_loja       182
# id_produto    182
# dt_venda      182
# dtype: int64

# %%
dfVendas.describe()
# Out:
#                 id   id_cliente      id_loja   id_produto
# count  3000.000000  3000.000000  3000.000000  3000.000000
# mean   1500.500000   500.763667     4.538333     4.435000
# std     866.169729   285.322282     2.922221     2.511018
# min       1.000000     1.000000     1.000000     1.000000
# 25%     750.750000   254.750000     2.000000     3.000000
# 50%    1500.500000   503.500000     4.000000     3.000000
# 75%    2250.250000   742.000000     7.000000     6.000000
# max    3000.000000  1000.000000    10.000000    10.000000

# %%
dfPag.describe()
# Out:
#                 id     id_venda
# count  2072.000000  2072.000000
# mean   1036.500000  1491.731660
# std     598.279199   864.865583
# min       1.000000     1.000000
# 25%     518.750000   746.250000
# 50%    1036.500000  1501.500000
# 75%    1554.250000  2220.500000
# max    2072.000000  2997.000000

# %% [markdown]
# Testes

# %%
dfVendas
# Out:
#         id  id_cliente  id_loja  id_produto   dt_venda
# 0        1         393        9           3 2018-01-04
# 1        2         417        9           3 2018-01-04
# 2        3         374        7           8 2018-01-04
# 3        4          59        4           3 2018-01-05
# 4        5          18        9           1 2018-01-05
# ...    ...         ...      ...         ...        ...
# 2995  2996         671        3           7 2020-09-27
# 2996  2997         586        8           3 2020-09-27
# 2997  2998         731        2           4 2020-09-27
# 2998  2999         163        2           1 2020-09-27
# 2999  3000         770        2           2 2020-09-27
#
# [3000 rows x 5 columns]

# %%
dfVendas.sample(10)
# Out:
#         id  id_cliente  id_loja  id_produto   dt_venda
# 1955  1956         990       10           9 2019-10-09
# 1564  1565         317        6           3 2019-06-09
# 2975  2976         882        2           3 2020-09-20
# 34      35         378        7           3 2018-01-14
# 1432  1433           3        3           3 2019-04-25
# 2964  2965         869        6           8 2020-09-17
# 1877  1878         901        6           3 2019-09-14
# 2092  2093         803        2           3 2019-12-04
# 2905  2906         340        1           3 2020-08-23
# 2760  2761         320        3           3 2020-07-10

# %%
dfLojas
# Out:
#    id          cidade
# 0   1       São Paulo
# 1   2  Rio de Janeiro
# 2   3        Curitiba
# 3   4  Belo Horizonte
# 4   5  Santa Catarina
# 5   6          Recife
# 6   7        Salvador
# 7   8        Brasília
# 8   9          Palmas
# 9  10         Vitória

# %%
dfPag
# Out:
#         id  id_venda    dt_pgto
# 0        1         1 2018-01-24
# 1        2         2 2018-02-17
# 2        3         3 2018-02-14
# 3        4         5 2018-01-23
# 4        5         7 2018-02-15
# ...    ...       ...        ...
# 2067  2068      2990 2020-10-04
# 2068  2069      2992 2020-10-10
# 2069  2070      2994 2020-10-09
# 2070  2071      2996 2020-10-17
# 2071  2072      2997 2020-10-02
#
# [2072 rows x 3 columns]

# %%
dfVendas[dfVendas.isnull().T.any()]
# Out:
# Empty DataFrame
# Columns: [id, id_cliente, id_loja, id_produto, dt_venda]
# Index: []

# %%
dfLojas.isnull().sum()
# Out:
# id        0
# cidade    0
# dtype: int64

# %%
dfVendas.sample(5)
# Out:
#         id  id_cliente  id_loja  id_produto   dt_venda
# 1362  1363         706        2           3 2019-03-26
# 2786  2787         374        5           8 2020-07-16
# 669    670         401        2           3 2018-08-05
# 2178  2179         958        2           3 2020-01-02
# 2915  2916         100        1           2 2020-08-28

# %% [markdown]
# DADOS NULOS

# %%
dfClientes.loc[dfClientes.nome.isnull(),'nome'] = 'Sem Nome'
dfClientes.loc[dfClientes.sexo.isnull(),'sexo'] = 'O'
dfClientes.loc[dfClientes.dt_nasc.isnull(),'dt_nasc'] = '1/1/2020'

# %%
dfClientes.loc[[269,287], :]
# Out:
#       id            nome sexo     dt_nasc
# 269  270        Sem Nome    M    1/1/2020
# 287  288  Victor Ribeiro    O  12/17/1974

# %%
dfClientes.isnull().sum()
# Out:
# id         0
# nome       0
# sexo       0
# dt_nasc    0
# dtype: int64

# %%
dfPag.isnull().sum()
# Out:
# id          0
# id_venda    0
# dt_pgto     0
# dtype: int64

# %% [markdown]
# Outliers

# %%
dfProdutos.loc[9,'valor'] = dfProdutos.valor[9]/10000
dfProdutos
# Out:
#    id        produto      valor
# 0   1          mouse    20.0000
# 1   2        teclado    30.0000
# 2   3  laptop básico  2300.0000
# 3   4   laptop gamer  5300.0000
# 4   5        monitor  1500.0000
# 5   6     impressora   700.0000
# 6   7     carregador   150.0000
# 7   8        cadeira   540.0000
# 8   9           mesa   860.0000
# 9  10       xxx-231a   321.1352

# %%
dfProdutos.boxplot(column=['valor'])

# %%
import matplotlib.pyplot as plt
import random

vetor = []

for i in range(12):
  num_aleatorio = random.randint(5,10)
  vetor.append(num_aleatorio)

print(vetor)

plt.boxplot(vetor)
# Out:
# [8, 10, 6, 8, 8, 6, 6, 8, 9, 10, 6, 5]
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff2be766690>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff2be770150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff2be766110>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff2be770c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff2be758650>],
#  'means': []}
