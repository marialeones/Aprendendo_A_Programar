# %% [markdown]
# <a href="https://colab.research.google.com/github/marialeones/Aprendendo_A_Programar/blob/main/aula_de_lista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tkinter import *

'Tratamento com listas em python...'

def adicionar_elemento(lista: list, elemento: str) -> bool:
    '''
    Verifica se o elemento começa com letra maiúscula
    Se ele passar na verificação, inserir na lista e retornar
    verdadeiro, caso contrário, retorne falso
    '''
    letra1 = elemento[0]
    if (letra1 == letra1.upper()):
        lista.append(elemento)
        return True
    else:
        return False
    

def buscar_elemento():
  lista = ['gato', 'peixe', 'fruta', 'goiaba']

  if 'avião' in lista:
    return True
  else:
    return False




def remover_elemento():
  lista1 = ['comida', 'festa', 'viagens', 'distância']
 
  if 'comida' in lista1:
    lista1.remove('comida')
  
    return True
  else:
    return False





def limpar_lista():
  lista = ['comida', 'festa', 'viagens', 'distância']
  lista.clear()
  print('a lista está vazia', lista)




def ordenar_lista():
  lista = ['comida', 'festa', 'viagens', 'distância', 'felicidade', 'amora']
  lista.sort()
  print('a lista está ordenada em ordem alfabetica ' ,lista)





def pegar_quantidade():
  lista = ['comida', 'festa', 'viagens', 'distância', 'felicidade' ]
  print('a quantidade de elemento na lista é ', len(lista))
  




def converter_maiusculo():
  lista = ['comida', 'festa', 'viagens', 'distância', 'felicidade']
  for i in range(len(lista)):
    lista[i] = lista[i].upper()

  print(lista)





def eliminar_repetidos():
  lista = ['comida', 'festa', 'viagens', 'distância', 'felicidade', 'festa', 'comida']
  lista.remove('comida')
  lista.remove('festa')
  lista1 = ['1','a', '4', 'b']
  lista = lista1
  print(lista1)

# %%
if elemento in lista:
  return True
  else:
    return False



if elemento in lista:
  lista.remove(elemento)
  return True
  else:
    return False


if c in range():
  lista.clear()


  if c in lista():
    lista.sort()


if c in range():
  len(lista)


  
    for i in range(len(lista)):
      lista[i] = lista[i].upper()



      if c in range(lista == lista):
        lista.remover()
        lista()
